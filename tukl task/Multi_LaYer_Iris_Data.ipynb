# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/iris.csv')

# %%
df.head(10)
df.head(30)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# 13           4.3          3.0           1.1          0.1  setosa
# 14           5.8          4.0           1.2          0.2  setosa
# 15           5.7          4.4           1.5          0.4  setosa
# 16           5.4          3.9           1.3          0.4  setosa
# 17           5.1          3.5           1.4          0.3  setosa
# 18           5.7          3.8           1.7          0.3  setosa
# 19           5.1          3.8           1.5          0.3  setosa
# 20           5.4          3.4           1.7          0.2  setosa
# 21           5.1          3.7           1.5          0.4  setosa
# 22           4.6          3.6           1.0          0.2  setosa
# 23           5.1          3.3           1.7          0.5  setosa
# 24           4.8          3.4           1.9          0.2  setosa
# 25           5.0          3.0           1.6          0.2  setosa
# 26           5.0          3.4           1.6          0.4  setosa
# 27           5.2          3.5           1.5          0.2  setosa
# 28           5.2          3.4           1.4          0.2  setosa
# 29           4.7          3.2           1.6          0.2  setosa

# %%
  y = pd.get_dummies(df["species"])
  y = y.astype(int)
  y
# Out:
#      setosa  versicolor  virginica
# 0         1           0          0
# 1         1           0          0
# 2         1           0          0
# 3         1           0          0
# 4         1           0          0
# ..      ...         ...        ...
# 145       0           0          1
# 146       0           0          1
# 147       0           0          1
# 148       0           0          1
# 149       0           0          1
#
# [150 rows x 3 columns]

# %%
x= df.drop(['species'],axis=1)
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 104           6.5          3.0           5.8          2.2
# 71            6.1          2.8           4.0          1.3
# 66            5.6          3.0           4.5          1.5
# 54            6.5          2.8           4.6          1.5
# 145           6.7          3.0           5.2          2.3
# ..            ...          ...           ...          ...
# 149           5.9          3.0           5.1          1.8
# 128           6.4          2.8           5.6          2.1
# 53            5.5          2.3           4.0          1.3
# 101           5.8          2.7           5.1          1.9
# 79            5.7          2.6           3.5          1.0
#
# [105 rows x 4 columns]

# %%
y_train
# Out:
#      setosa  versicolor  virginica
# 104       0           0          1
# 71        0           1          0
# 66        0           1          0
# 54        0           1          0
# 145       0           0          1
# ..      ...         ...        ...
# 149       0           0          1
# 128       0           0          1
# 53        0           1          0
# 101       0           0          1
# 79        0           1          0
#
# [105 rows x 3 columns]

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(36,activation="sigmoid")) #hidden
# model.add(Dense(6,activation="sigmoid")) #hidden

# %%
model.add(Dense(3,activation="softmax"))

# %%
model.compile(loss="categorical_crossentropy",metrics=["accuracy"])
model.fit(x_train,y_train,epochs=25,batch_size=5)
# Out:
# Epoch 1/25
# 21/21 [==============================] - 1s 3ms/step - loss: 1.1567 - accuracy: 0.1429
# Epoch 2/25
# 21/21 [==============================] - 0s 3ms/step - loss: 1.0640 - accuracy: 0.2952
# Epoch 3/25
# 21/21 [==============================] - 0s 3ms/step - loss: 1.0169 - accuracy: 0.6952
# Epoch 4/25
# 21/21 [==============================] - 0s 3ms/step - loss: 0.9759 - accuracy: 0.7048
# Epoch 5/25
# 21/21 [==============================] - 0s 3ms/step - loss: 0.9386 - accuracy: 0.7048
# Epoch 6/25
# 21/21 [==============================] - 0s 2ms/step - loss: 0.9011 - accuracy: 0.7048
# Epoch 7/25
# 21/21 [==============================] - 0s 2ms/step - loss: 0.8645 - accuracy: 0.7048
# Epoch 8/25
# 21/21 [==============================] - 0s 2ms/step - loss: 0.8315 - accuracy: 0.7238
# Epoch 9/25
# 21/21 [==============================] - 0s 3ms/step - loss: 0.7986 - accuracy: 0.7048
# Epoch 10/25
# 21/21 [==============================] - 0s 3ms/step - loss: 0.7676 - accuracy: 0.7048
# Epoch 11/25
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7375 - accuracy: 0.7714
# Epoch 12/25
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7123 - accuracy: 0.7048
# Epoch 13/25
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6854 - accuracy: 0.7238
# Epoch 14/25
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6628 - accuracy: 0.7714
# Epoch 15/25
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6371 - accuracy: 0.7524
# Epoch 16/25
# 21/21 [==============================] - 0s 3ms/step - loss: 0.6128 - accuracy: 0.7333
# Epoch 17/25
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5896 - accuracy: 0.8286
# Epoch 18/25
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5708 - accuracy: 0.7810
# Epoch 19/25
# 21/21 [==============================] - 0s 3ms/step - loss: 0.5513 - accuracy: 0.7333
# Epoch 20/25
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5366 - accuracy: 0.8476
# Epoch 21/25
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5219 - accuracy: 0.7905
# Epoch 22/25
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5036 - accuracy: 0.8000
# Epoch 23/25
# 21/21 [==============================] - 0s 3ms/step - loss: 0.4899 - accuracy: 0.8571
# Epoch 24/25
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4760 - accuracy: 0.8571
# Epoch 25/25
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4643 - accuracy: 0.8667

# %%
score=model.evaluate(x_test,y_test)
print("Acuuracy :", score)
# Out:
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5233 - accuracy: 0.8889
# Acuuracy : [0.5233393907546997, 0.8888888955116272]

# %%
i=model.predict([[5.1,3.5,1.4,0.2]])
i
# Out:
# 1/1 [==============================] - 0s 29ms/step
# array([[0.8921447 , 0.09350052, 0.01435471]], dtype=float32)
