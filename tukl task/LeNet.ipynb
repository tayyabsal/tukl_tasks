# %%
from keras.datasets import mnist
from keras.layers import Dense,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras.models import Sequential

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()
x_train.shape
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# (60000, 28, 28)

# %%
x_train=x_train.reshape((x_train.shape[0],28,28,1))
x_test=x_test.reshape((x_test.shape[0],28,28,1))

# %%
x_train=x_train/255
x_test=x_test/255

# %%
import keras
y_train=keras.utils.to_categorical(y_train,10)
y_test=keras.utils.to_categorical(y_test,10)

# %%
model=Sequential()
model.add(Conv2D(96,(3,3),strides=1,input_shape=(28,28,1),activation="relu"))
model.add(MaxPooling2D((3,3),strides=2))
model.add(Conv2D(256, (5,5) ,padding='same',activation='relu'))
model.add(MaxPooling2D((3,3),strides=2))

# %%
model.add(Conv2D(384, (3,3),padding='same',activation='relu'))
model.add(Conv2D(384,(3,3),padding='same',activation='relu'))
model.add(Conv2D(256,(3,3),padding='same',activation='relu'))
model.add(MaxPooling2D((3,3),strides=2))
model.add(Flatten())
model.add(Dense(4096,activation='relu'))
model.add(Dense(4096,activation='relu'))
model.add(Dense(10,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_17 (Conv2D)          (None, 26, 26, 96)        960
#
#  max_pooling2d_7 (MaxPoolin  (None, 12, 12, 96)        0
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 12, 12, 256)       614656
#
#  max_pooling2d_8 (MaxPoolin  (None, 5, 5, 256)         0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 5, 5, 384)         885120
#
#  conv2d_20 (Conv2D)          (None, 5, 5, 384)         1327488
#
#  conv2d_21 (Conv2D)          (None, 5, 5, 256)         884992
#
#  max_pooling2d_9 (MaxPoolin  (None, 2, 2, 256)         0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 1024)              0
#
#  dense_5 (Dense)             (None, 4096)              4198400
#
#  dense_6 (Dense)             (None, 4096)              16781312
#
#  dense_7 (Dense)             (None, 10)                40970
#
# =================================================================
# Total params: 24733898 (94.35 MB)
# Trainable params: 24733898 (94.35 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss=keras.metrics.categorical_crossentropy,optimizer=keras.optimizers.Adam(),metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=25,batch_size=128)
# Out:
# Epoch 1/25
# 469/469 [==============================] - 1978s 4s/step - loss: 0.2844 - accuracy: 0.9039
# Epoch 2/25
# 469/469 [==============================] - 1966s 4s/step - loss: 0.0499 - accuracy: 0.9853
# Epoch 3/25
# 342/469 [====================>.........] - ETA: 8:59 - loss: 0.0425 - accuracy: 0.9876

# %%
score=model.evaluate(x_test,y_test)
print("Acc",score)
