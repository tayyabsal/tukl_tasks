# %%
import tensorflow.keras
from tensorflow.keras.layers import Input,Conv2D,DepthwiseConv2D,BatchNormalization,ReLU,GlobalAveragePooling2D,Dense
from tensorflow.keras.models import Model

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
def depth_block(x, strides):

  x = DepthwiseConv2D(3,strides=strides,padding='same',  use_bias=False)(x)
  x = BatchNormalization()(x)
  x = ReLU()(x)
  return x
def single_conv_block(x,filters):
    x = Conv2D(filters, 1,use_bias=False)(x)
    x= BatchNormalization()(x)
    x = ReLU()(x)
    return x
def combo_layer(x,filters,strides):

  x = depth_block(x,strides)
  x = single_conv_block(x, filters)
  return x
def MobileNet(input_shape=(224,224,3),n_classes = 1000):
    input = Input ( input_shape)
    x = Conv2D(32,3,strides=(2,2),padding = 'same', use_bias=False) (input)
    x =  BatchNormalization()(x)
    x = ReLU()(x)
    x = combo_layer(x,64, strides=(1,1))
    x = combo_layer(x,128,strides=(2,2))
    x = combo_layer(x,128,strides=(1,1))
    x = combo_layer(x,256,strides=(2,2))
    x = combo_layer(x,256,strides=(1,1))
    x = combo_layer(x,512,strides=(2,2))
    for _ in range(5):
      x = combo_layer(x,512,strides=(1,1))
    x = combo_layer(x,1024,strides=(2,2))
    x = combo_layer(x,1024,strides=(1,1))
    x = GlobalAveragePooling2D()(x)
    output = Dense(n_classes,activation='softmax')(x)
    model = Model(input, output)
    return model

# %%
 n_classes = 1000
 input_shape = (224,224,3)
 model = MobileNet(input_shape,n_classes)
 model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d_21 (Conv2D)          (None, 112, 112, 32)      864
#
#  batch_normalization_35 (Ba  (None, 112, 112, 32)      128
#  tchNormalization)
#
#  re_lu_35 (ReLU)             (None, 112, 112, 32)      0
#
#  depthwise_conv2d_14 (Depth  (None, 112, 112, 32)      288
#  wiseConv2D)
#
#  batch_normalization_36 (Ba  (None, 112, 112, 32)      128
#  tchNormalization)
#
#  re_lu_36 (ReLU)             (None, 112, 112, 32)      0
#
#  conv2d_22 (Conv2D)          (None, 112, 112, 64)      2048
#
#  batch_normalization_37 (Ba  (None, 112, 112, 64)      256
#  tchNormalization)
#
#  re_lu_37 (ReLU)             (None, 112, 112, 64)      0
#
#  depthwise_conv2d_15 (Depth  (None, 56, 56, 64)        576
#  wiseConv2D)
#
#  batch_normalization_38 (Ba  (None, 56, 56, 64)        256
#  tchNormalization)
#
#  re_lu_38 (ReLU)             (None, 56, 56, 64)        0
#
#  conv2d_23 (Conv2D)          (None, 56, 56, 128)       8192
#
#  batch_normalization_39 (Ba  (None, 56, 56, 128)       512
#  tchNormalization)
#
#  re_lu_39 (ReLU)             (None, 56, 56, 128)       0
#
#  depthwise_conv2d_16 (Depth  (None, 56, 56, 128)       1152
#  wiseConv2D)
#
#  batch_normalization_40 (Ba  (None, 56, 56, 128)       512
#  tchNormalization)
#
#  re_lu_40 (ReLU)             (None, 56, 56, 128)       0
#
#  conv2d_24 (Conv2D)          (None, 56, 56, 128)       16384
#
#  batch_normalization_41 (Ba  (None, 56, 56, 128)       512
#  tchNormalization)
#
#  re_lu_41 (ReLU)             (None, 56, 56, 128)       0
#
#  depthwise_conv2d_17 (Depth  (None, 28, 28, 128)       1152
#  wiseConv2D)
#
#  batch_normalization_42 (Ba  (None, 28, 28, 128)       512
#  tchNormalization)
#
#  re_lu_42 (ReLU)             (None, 28, 28, 128)       0
#
#  conv2d_25 (Conv2D)          (None, 28, 28, 256)       32768
#
#  batch_normalization_43 (Ba  (None, 28, 28, 256)       1024
#  tchNormalization)
#
#  re_lu_43 (ReLU)             (None, 28, 28, 256)       0
#
#  depthwise_conv2d_18 (Depth  (None, 28, 28, 256)       2304
#  wiseConv2D)
#
#  batch_normalization_44 (Ba  (None, 28, 28, 256)       1024
#  tchNormalization)
#
#  re_lu_44 (ReLU)             (None, 28, 28, 256)       0
#
#  conv2d_26 (Conv2D)          (None, 28, 28, 256)       65536
#
#  batch_normalization_45 (Ba  (None, 28, 28, 256)       1024
#  tchNormalization)
#
#  re_lu_45 (ReLU)             (None, 28, 28, 256)       0
#
#  depthwise_conv2d_19 (Depth  (None, 14, 14, 256)       2304
#  wiseConv2D)
#
#  batch_normalization_46 (Ba  (None, 14, 14, 256)       1024
#  tchNormalization)
#
#  re_lu_46 (ReLU)             (None, 14, 14, 256)       0
#
#  conv2d_27 (Conv2D)          (None, 14, 14, 512)       131072
#
#  batch_normalization_47 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_47 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_20 (Depth  (None, 14, 14, 512)       4608
#  wiseConv2D)
#
#  batch_normalization_48 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_48 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_28 (Conv2D)          (None, 14, 14, 512)       262144
#
#  batch_normalization_49 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_49 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_21 (Depth  (None, 14, 14, 512)       4608
#  wiseConv2D)
#
#  batch_normalization_50 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_50 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_29 (Conv2D)          (None, 14, 14, 512)       262144
#
#  batch_normalization_51 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_51 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_22 (Depth  (None, 14, 14, 512)       4608
#  wiseConv2D)
#
#  batch_normalization_52 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_52 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_30 (Conv2D)          (None, 14, 14, 512)       262144
#
#  batch_normalization_53 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_53 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_23 (Depth  (None, 14, 14, 512)       4608
#  wiseConv2D)
#
#  batch_normalization_54 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_54 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_31 (Conv2D)          (None, 14, 14, 512)       262144
#
#  batch_normalization_55 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_55 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_24 (Depth  (None, 14, 14, 512)       4608
#  wiseConv2D)
#
#  batch_normalization_56 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_56 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_32 (Conv2D)          (None, 14, 14, 512)       262144
#
#  batch_normalization_57 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_57 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_25 (Depth  (None, 7, 7, 512)         4608
#  wiseConv2D)
#
#  batch_normalization_58 (Ba  (None, 7, 7, 512)         2048
#  tchNormalization)
#
#  re_lu_58 (ReLU)             (None, 7, 7, 512)         0
#
#  conv2d_33 (Conv2D)          (None, 7, 7, 1024)        524288
#
#  batch_normalization_59 (Ba  (None, 7, 7, 1024)        4096
#  tchNormalization)
#
#  re_lu_59 (ReLU)             (None, 7, 7, 1024)        0
#
#  depthwise_conv2d_26 (Depth  (None, 7, 7, 1024)        9216
#  wiseConv2D)
#
#  batch_normalization_60 (Ba  (None, 7, 7, 1024)        4096
#  tchNormalization)
#
#  re_lu_60 (ReLU)             (None, 7, 7, 1024)        0
#
#  conv2d_34 (Conv2D)          (None, 7, 7, 1024)        1048576
#
#  batch_normalization_61 (Ba  (None, 7, 7, 1024)        4096
#  tchNormalization)
#
#  re_lu_61 (ReLU)             (None, 7, 7, 1024)        0
#
#  global_average_pooling2d_1  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 1000)              1025000
#
# =================================================================
# Total params: 4253864 (16.23 MB)
# Trainable params: 4231976 (16.14 MB)
# Non-trainable params: 21888 (85.50 KB)
# _________________________________________________________________

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model, Input
from tensorflow.keras.layers import Conv2D, DepthwiseConv2D, BatchNormalization, ReLU, GlobalAveragePooling2D, Dense

def depth_block(x, strides):
    x = DepthwiseConv2D(3, strides=strides, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    return x

def single_conv_block(x, filters):
    x = Conv2D(filters, 1, use_bias=False)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    return x

def combo_layer(x, filters, strides):
    x = depth_block(x, strides)
    x = single_conv_block(x, filters)
    return x

def MobileNet(input_shape=(224, 224, 3), n_classes=1000):
    input = Input(input_shape)
    x = Conv2D(32, 3, strides=(2, 2), padding='same', use_bias=False)(input)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = combo_layer(x, 64, strides=(1, 1))
    x = combo_layer(x, 128, strides=(2, 2))
    x = combo_layer(x, 128, strides=(1, 1))
    x = combo_layer(x, 256, strides=(2, 2))
    x = combo_layer(x, 256, strides=(1, 1))
    x = combo_layer(x, 512, strides=(2, 2))
    for _ in range(5):
        x = combo_layer(x, 512, strides=(1, 1))
    x = combo_layer(x, 1024, strides=(2, 2))
    x = combo_layer(x, 1024, strides=(1, 1))
    x = GlobalAveragePooling2D()(x)
    output = Dense(n_classes, activation='softmax')(x)
    model = Model(input, output)
    return model

# Specify the input shape and number of classes
input_shape = (224, 224, 3)
n_classes = 1000

# Build the model
model = MobileNet(input_shape, n_classes)

# Print the model summary
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d_6 (Conv2D)           (None, 112, 112, 32)      864
#
#  batch_normalization_6 (Bat  (None, 112, 112, 32)      128
#  chNormalization)
#
#  re_lu_6 (ReLU)              (None, 112, 112, 32)      0
#
#  depthwise_conv2d (Depthwis  (None, 112, 112, 32)      288
#  eConv2D)
#
#  batch_normalization_7 (Bat  (None, 112, 112, 32)      128
#  chNormalization)
#
#  re_lu_7 (ReLU)              (None, 112, 112, 32)      0
#
#  conv2d_7 (Conv2D)           (None, 112, 112, 64)      2048
#
#  batch_normalization_8 (Bat  (None, 112, 112, 64)      256
#  chNormalization)
#
#  re_lu_8 (ReLU)              (None, 112, 112, 64)      0
#
#  depthwise_conv2d_1 (Depthw  (None, 56, 56, 64)        576
#  iseConv2D)
#
#  batch_normalization_9 (Bat  (None, 56, 56, 64)        256
#  chNormalization)
#
#  re_lu_9 (ReLU)              (None, 56, 56, 64)        0
#
#  conv2d_8 (Conv2D)           (None, 56, 56, 128)       8192
#
#  batch_normalization_10 (Ba  (None, 56, 56, 128)       512
#  tchNormalization)
#
#  re_lu_10 (ReLU)             (None, 56, 56, 128)       0
#
#  depthwise_conv2d_2 (Depthw  (None, 56, 56, 128)       1152
#  iseConv2D)
#
#  batch_normalization_11 (Ba  (None, 56, 56, 128)       512
#  tchNormalization)
#
#  re_lu_11 (ReLU)             (None, 56, 56, 128)       0
#
#  conv2d_9 (Conv2D)           (None, 56, 56, 128)       16384
#
#  batch_normalization_12 (Ba  (None, 56, 56, 128)       512
#  tchNormalization)
#
#  re_lu_12 (ReLU)             (None, 56, 56, 128)       0
#
#  depthwise_conv2d_3 (Depthw  (None, 28, 28, 128)       1152
#  iseConv2D)
#
#  batch_normalization_13 (Ba  (None, 28, 28, 128)       512
#  tchNormalization)
#
#  re_lu_13 (ReLU)             (None, 28, 28, 128)       0
#
#  conv2d_10 (Conv2D)          (None, 28, 28, 256)       32768
#
#  batch_normalization_14 (Ba  (None, 28, 28, 256)       1024
#  tchNormalization)
#
#  re_lu_14 (ReLU)             (None, 28, 28, 256)       0
#
#  depthwise_conv2d_4 (Depthw  (None, 28, 28, 256)       2304
#  iseConv2D)
#
#  batch_normalization_15 (Ba  (None, 28, 28, 256)       1024
#  tchNormalization)
#
#  re_lu_15 (ReLU)             (None, 28, 28, 256)       0
#
#  conv2d_11 (Conv2D)          (None, 28, 28, 256)       65536
#
#  batch_normalization_16 (Ba  (None, 28, 28, 256)       1024
#  tchNormalization)
#
#  re_lu_16 (ReLU)             (None, 28, 28, 256)       0
#
#  depthwise_conv2d_5 (Depthw  (None, 14, 14, 256)       2304
#  iseConv2D)
#
#  batch_normalization_17 (Ba  (None, 14, 14, 256)       1024
#  tchNormalization)
#
#  re_lu_17 (ReLU)             (None, 14, 14, 256)       0
#
#  conv2d_12 (Conv2D)          (None, 14, 14, 512)       131072
#
#  batch_normalization_18 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_18 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_6 (Depthw  (None, 14, 14, 512)       4608
#  iseConv2D)
#
#  batch_normalization_19 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_19 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_13 (Conv2D)          (None, 14, 14, 512)       262144
#
#  batch_normalization_20 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_20 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_7 (Depthw  (None, 14, 14, 512)       4608
#  iseConv2D)
#
#  batch_normalization_21 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_21 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_14 (Conv2D)          (None, 14, 14, 512)       262144
#
#  batch_normalization_22 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_22 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_8 (Depthw  (None, 14, 14, 512)       4608
#  iseConv2D)
#
#  batch_normalization_23 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_23 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_15 (Conv2D)          (None, 14, 14, 512)       262144
#
#  batch_normalization_24 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_24 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_9 (Depthw  (None, 14, 14, 512)       4608
#  iseConv2D)
#
#  batch_normalization_25 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_25 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_16 (Conv2D)          (None, 14, 14, 512)       262144
#
#  batch_normalization_26 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_26 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_10 (Depth  (None, 14, 14, 512)       4608
#  wiseConv2D)
#
#  batch_normalization_27 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_27 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_17 (Conv2D)          (None, 14, 14, 512)       262144
#
#  batch_normalization_28 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_28 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_11 (Depth  (None, 7, 7, 512)         4608
#  wiseConv2D)
#
#  batch_normalization_29 (Ba  (None, 7, 7, 512)         2048
#  tchNormalization)
#
#  re_lu_29 (ReLU)             (None, 7, 7, 512)         0
#
#  conv2d_18 (Conv2D)          (None, 7, 7, 1024)        524288
#
#  batch_normalization_30 (Ba  (None, 7, 7, 1024)        4096
#  tchNormalization)
#
#  re_lu_30 (ReLU)             (None, 7, 7, 1024)        0
#
#  depthwise_conv2d_12 (Depth  (None, 7, 7, 1024)        9216
#  wiseConv2D)
#
#  batch_normalization_31 (Ba  (None, 7, 7, 1024)        4096
#  tchNormalization)
#
#  re_lu_31 (ReLU)             (None, 7, 7, 1024)        0
#
#  conv2d_19 (Conv2D)          (None, 7, 7, 1024)        1048576
#
#  batch_normalization_32 (Ba  (None, 7, 7, 1024)        4096
#  tchNormalization)
#
#  re_lu_32 (ReLU)             (None, 7, 7, 1024)        0
#
#  global_average_pooling2d (  (None, 1024)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1000)              1025000
#
# =================================================================
# Total params: 4253864 (16.23 MB)
# Trainable params: 4231976 (16.14 MB)
# Non-trainable params: 21888 (85.50 KB)
# _________________________________________________________________

# %%
from keras.datasets import mnist
from keras.layers import Dense,Flatten
from keras.layers import Conv2D,MaxPooling2D
from keras.models import Sequential

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()
x_train.shape
# Out:
# (60000, 28, 28)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.image import resize

# %%
# Resize images from 28x28 to 224x224
x_train_resized = np.array([resize(image.reshape(28, 28, 1), [224, 224]).numpy() for image in x_train])
x_test_resized = np.array([resize(image.reshape(28, 28, 1), [224, 224]).numpy() for image in x_test])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5014e8f727cc> in <cell line: 2>()
#       1 # Resize images from 28x28 to 224x224
# ----> 2 x_train_resized = np.array([resize(image.reshape(28, 28, 1), [224, 224]).numpy() for image in x_train])
#       3 x_test_resized = np.array([resize(image.reshape(28, 28, 1), [224, 224]).numpy() for image in x_test])
#
# NameError: name 'np' is not defined

# %%
# Normalize the images
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Convert labels to one-hot encoding
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

def image_generator(images, labels, batch_size):
    while True:
        for start in range(0, len(images), batch_size):
            end = min(start + batch_size, len(images))
            batch_images = images[start:end]
            batch_labels = labels[start:end]
            # Resize images and expand to 3 channels
            batch_images_resized = np.array([resize(image.reshape(28, 28, 1), [224, 224]).numpy() for image in batch_images])
            batch_images_resized = np.repeat(batch_images_resized, 3, axis=-1)
            yield batch_images_resized, batch_labels

# Define batch size
batch_size = 32

# Create generators
train_gen = image_generator(x_train, y_train, batch_size)
test_gen = image_generator(x_test, y_test, batch_size)

# %%
x_batch, y_batch = next(train_gen)

print(f"Batch images shape: {x_batch.shape}")
print(f"Batch labels shape: {y_batch.shape}")
# Out:
# Batch images shape: (32, 224, 224, 3)
# Batch labels shape: (32, 10)

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model, Input
from tensorflow.keras.layers import Conv2D, DepthwiseConv2D, BatchNormalization, ReLU, GlobalAveragePooling2D, Dense

def depth_block(x, strides):
    x = DepthwiseConv2D(3, strides=strides, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    return x

def single_conv_block(x, filters):
    x = Conv2D(filters, 1, use_bias=False)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    return x

def combo_layer(x, filters, strides):
    x = depth_block(x, strides)
    x = single_conv_block(x, filters)
    return x

def MobileNet(input_shape=(224, 224, 3), n_classes=10):
    input = Input(input_shape)
    x = Conv2D(32, 3, strides=(2, 2), padding='same', use_bias=False)(input)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = combo_layer(x, 64, strides=(1, 1))
    x = combo_layer(x, 128, strides=(2, 2))
    x = combo_layer(x, 128, strides=(1, 1))
    x = combo_layer(x, 256, strides=(2, 2))
    x = combo_layer(x, 256, strides=(1, 1))
    x = combo_layer(x, 512, strides=(2, 2))
    for _ in range(5):
        x = combo_layer(x, 512, strides=(1, 1))
    x = combo_layer(x, 1024, strides=(2, 2))
    x = combo_layer(x, 1024, strides=(1, 1))
    x = GlobalAveragePooling2D()(x)
    output = Dense(n_classes, activation='softmax')(x)
    model = Model(input, output)
    return model

# Specify the input shape and number of classes
input_shape = (224, 224, 3)
n_classes = 10

# Build the model
model = MobileNet(input_shape, n_classes)

# Print the model summary
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d_14 (Conv2D)          (None, 112, 112, 32)      864
#
#  batch_normalization_27 (Ba  (None, 112, 112, 32)      128
#  tchNormalization)
#
#  re_lu_27 (ReLU)             (None, 112, 112, 32)      0
#
#  depthwise_conv2d_13 (Depth  (None, 112, 112, 32)      288
#  wiseConv2D)
#
#  batch_normalization_28 (Ba  (None, 112, 112, 32)      128
#  tchNormalization)
#
#  re_lu_28 (ReLU)             (None, 112, 112, 32)      0
#
#  conv2d_15 (Conv2D)          (None, 112, 112, 64)      2048
#
#  batch_normalization_29 (Ba  (None, 112, 112, 64)      256
#  tchNormalization)
#
#  re_lu_29 (ReLU)             (None, 112, 112, 64)      0
#
#  depthwise_conv2d_14 (Depth  (None, 56, 56, 64)        576
#  wiseConv2D)
#
#  batch_normalization_30 (Ba  (None, 56, 56, 64)        256
#  tchNormalization)
#
#  re_lu_30 (ReLU)             (None, 56, 56, 64)        0
#
#  conv2d_16 (Conv2D)          (None, 56, 56, 128)       8192
#
#  batch_normalization_31 (Ba  (None, 56, 56, 128)       512
#  tchNormalization)
#
#  re_lu_31 (ReLU)             (None, 56, 56, 128)       0
#
#  depthwise_conv2d_15 (Depth  (None, 56, 56, 128)       1152
#  wiseConv2D)
#
#  batch_normalization_32 (Ba  (None, 56, 56, 128)       512
#  tchNormalization)
#
#  re_lu_32 (ReLU)             (None, 56, 56, 128)       0
#
#  conv2d_17 (Conv2D)          (None, 56, 56, 128)       16384
#
#  batch_normalization_33 (Ba  (None, 56, 56, 128)       512
#  tchNormalization)
#
#  re_lu_33 (ReLU)             (None, 56, 56, 128)       0
#
#  depthwise_conv2d_16 (Depth  (None, 28, 28, 128)       1152
#  wiseConv2D)
#
#  batch_normalization_34 (Ba  (None, 28, 28, 128)       512
#  tchNormalization)
#
#  re_lu_34 (ReLU)             (None, 28, 28, 128)       0
#
#  conv2d_18 (Conv2D)          (None, 28, 28, 256)       32768
#
#  batch_normalization_35 (Ba  (None, 28, 28, 256)       1024
#  tchNormalization)
#
#  re_lu_35 (ReLU)             (None, 28, 28, 256)       0
#
#  depthwise_conv2d_17 (Depth  (None, 28, 28, 256)       2304
#  wiseConv2D)
#
#  batch_normalization_36 (Ba  (None, 28, 28, 256)       1024
#  tchNormalization)
#
#  re_lu_36 (ReLU)             (None, 28, 28, 256)       0
#
#  conv2d_19 (Conv2D)          (None, 28, 28, 256)       65536
#
#  batch_normalization_37 (Ba  (None, 28, 28, 256)       1024
#  tchNormalization)
#
#  re_lu_37 (ReLU)             (None, 28, 28, 256)       0
#
#  depthwise_conv2d_18 (Depth  (None, 14, 14, 256)       2304
#  wiseConv2D)
#
#  batch_normalization_38 (Ba  (None, 14, 14, 256)       1024
#  tchNormalization)
#
#  re_lu_38 (ReLU)             (None, 14, 14, 256)       0
#
#  conv2d_20 (Conv2D)          (None, 14, 14, 512)       131072
#
#  batch_normalization_39 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_39 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_19 (Depth  (None, 14, 14, 512)       4608
#  wiseConv2D)
#
#  batch_normalization_40 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_40 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_21 (Conv2D)          (None, 14, 14, 512)       262144
#
#  batch_normalization_41 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_41 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_20 (Depth  (None, 14, 14, 512)       4608
#  wiseConv2D)
#
#  batch_normalization_42 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_42 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_22 (Conv2D)          (None, 14, 14, 512)       262144
#
#  batch_normalization_43 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_43 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_21 (Depth  (None, 14, 14, 512)       4608
#  wiseConv2D)
#
#  batch_normalization_44 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_44 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_23 (Conv2D)          (None, 14, 14, 512)       262144
#
#  batch_normalization_45 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_45 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_22 (Depth  (None, 14, 14, 512)       4608
#  wiseConv2D)
#
#  batch_normalization_46 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_46 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_24 (Conv2D)          (None, 14, 14, 512)       262144
#
#  batch_normalization_47 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_47 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_23 (Depth  (None, 14, 14, 512)       4608
#  wiseConv2D)
#
#  batch_normalization_48 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_48 (ReLU)             (None, 14, 14, 512)       0
#
#  conv2d_25 (Conv2D)          (None, 14, 14, 512)       262144
#
#  batch_normalization_49 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  re_lu_49 (ReLU)             (None, 14, 14, 512)       0
#
#  depthwise_conv2d_24 (Depth  (None, 7, 7, 512)         4608
#  wiseConv2D)
#
#  batch_normalization_50 (Ba  (None, 7, 7, 512)         2048
#  tchNormalization)
#
#  re_lu_50 (ReLU)             (None, 7, 7, 512)         0
#
#  conv2d_26 (Conv2D)          (None, 7, 7, 1024)        524288
#
#  batch_normalization_51 (Ba  (None, 7, 7, 1024)        4096
#  tchNormalization)
#
#  re_lu_51 (ReLU)             (None, 7, 7, 1024)        0
#
#  depthwise_conv2d_25 (Depth  (None, 7, 7, 1024)        9216
#  wiseConv2D)
#
#  batch_normalization_52 (Ba  (None, 7, 7, 1024)        4096
#  tchNormalization)
#
#  re_lu_52 (ReLU)             (None, 7, 7, 1024)        0
#
#  conv2d_27 (Conv2D)          (None, 7, 7, 1024)        1048576
#
#  batch_normalization_53 (Ba  (None, 7, 7, 1024)        4096
#  tchNormalization)
#
#  re_lu_53 (ReLU)             (None, 7, 7, 1024)        0
#
#  global_average_pooling2d_1  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 10)                10250
#
# =================================================================
# Total params: 3239114 (12.36 MB)
# Trainable params: 3217226 (12.27 MB)
# Non-trainable params: 21888 (85.50 KB)
# _________________________________________________________________

# %%
model.compile(loss=keras.metrics.categorical_crossentropy,optimizer=keras.optimizers.Adam(),metrics=['accuracy'])

# %%
model.fit(x_batch,y_batch,epochs=25,batch_size=128)
# Out:
# Epoch 1/25
# 1/1 [==============================] - 18s 18s/step - loss: 2.3292 - accuracy: 0.0625
# Epoch 2/25
# 1/1 [==============================] - 6s 6s/step - loss: 1.9411 - accuracy: 0.4375
# Epoch 3/25
# 1/1 [==============================] - 8s 8s/step - loss: 1.7835 - accuracy: 0.3438
# Epoch 4/25
# 1/1 [==============================] - 6s 6s/step - loss: 1.6576 - accuracy: 0.3125
# Epoch 5/25
# 1/1 [==============================] - 7s 7s/step - loss: 1.3662 - accuracy: 0.5312
# Epoch 6/25
# 1/1 [==============================] - 5s 5s/step - loss: 1.0267 - accuracy: 0.7188
# Epoch 7/25
# 1/1 [==============================] - 6s 6s/step - loss: 0.7883 - accuracy: 0.9375
# Epoch 8/25
# 1/1 [==============================] - 6s 6s/step - loss: 0.4690 - accuracy: 1.0000
# Epoch 9/25
# 1/1 [==============================] - 6s 6s/step - loss: 0.2628 - accuracy: 1.0000
# Epoch 10/25
# 1/1 [==============================] - 7s 7s/step - loss: 0.1468 - accuracy: 1.0000
# Epoch 11/25
# 1/1 [==============================] - 6s 6s/step - loss: 0.0661 - accuracy: 1.0000
# Epoch 12/25
# 1/1 [==============================] - 7s 7s/step - loss: 0.0394 - accuracy: 1.0000
# Epoch 13/25
# 1/1 [==============================] - 6s 6s/step - loss: 0.0227 - accuracy: 1.0000
# Epoch 14/25
# 1/1 [==============================] - 9s 9s/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 15/25
# 1/1 [==============================] - 8s 8s/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 16/25
# 1/1 [==============================] - 10s 10s/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 17/25
# 1/1 [==============================] - 7s 7s/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 18/25
# 1/1 [==============================] - 7s 7s/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 19/25
# 1/1 [==============================] - 6s 6s/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 20/25
# 1/1 [==============================] - 7s 7s/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 21/25
# 1/1 [==============================] - 6s 6s/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 22/25
# 1/1 [==============================] - 8s 8s/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 23/25
# 1/1 [==============================] - 5s 5s/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 24/25
# 1/1 [==============================] - 7s 7s/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 25/25
# 1/1 [==============================] - 5s 5s/step - loss: 0.0012 - accuracy: 1.0000

# %%
model.fit(
    train_gen,
    steps_per_epoch=len(x_train) // batch_size,
    epochs=10,
    validation_data=test_gen,
    validation_steps=len(x_test) // batch_size
)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 11643s 6s/step - loss: 0.1168 - accuracy: 0.9645 - val_loss: 0.0993 - val_accuracy: 0.9699
# Epoch 2/10
#  461/1875 [======>.......................] - ETA: 2:21:15 - loss: 0.0672 - accuracy: 0.9795
